# %% [markdown]
# Візуалізація даних
#
# Matplotlib

# %% [markdown]
# pip install matplotlib

# %% [markdown]
# Лінійні графіки

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start='2021-09-01', freq='D', periods=8)
plt.figure(figsize=(10, 6)) # (ширина, высота)
plt.plot(date, [23, 17, 17, 16, 15, 14, 17, 20])
plt.show()

# %% [markdown]
# Текст на графіках

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start='2021-09-01', freq='D', periods=8)
plt.figure(figsize=(10, 6)) # (ширина, высота)
plt.plot(date, [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature') # label - назва лінії
# plt.plot(date, [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature') 
plt.xlabel('Дата', fontsize='small', color='midnightblue') # виведення назви осі Х та характеристики тексту
plt.ylabel('Температура', fontsize='small', color='midnightblue') # виведення назви осі Y та характеристики тексту
plt.title('Температура в м. Полтава', fontsize=15) # титульний заголовок та характеристики тексту
plt.text(date[0], 15, 'Осінь досить тепла', color="blue") # коментар, координати та характеристики тексту
plt.legend() # виведення label='day temperature'
plt.show()

# %% [markdown]
# Компонування графіків

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start='2021-09-01', freq='D', periods=8)
fig, axs = plt.subplots()

axs.plot(date, [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
axs.plot(date, [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature')
plt.xlabel('Дата', fontsize='small', color='midnightblue')
plt.ylabel('Температура', fontsize='small', color='midnightblue')
plt.title('Температура в м. Полтава', fontsize=15)
plt.text(date[0], 15, 'Осінь досить тепла', color="blue")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start='2021-09-01', freq='D', periods=8)
fig, axs = plt.subplots(2, 1, figsize=(10, 6))

axs[0].plot(date, [23, 17, 17, 16, 15, 14, 17, 20], label='day temperature')
axs[1].plot(date, [19, 11, 16, 11, 10, 10, 11, 16], label='night temperature')

axs[0].set_title('Денна', fontsize=10)
axs[1].set_title('Нічна', fontsize=10)

fig.suptitle('Температура в м. Полтава', fontsize=15)

plt.show()

# %% [markdown]
# Налаштування графіків

# %% [markdown]
# ![alt text](265842cc-ffeb-4158-ae09-54a3ccba33ceScreenshot_18.png)

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start="2021-09-01", freq="D", periods=8)
plt.figure(figsize=(10, 6)) # (ширина, высота)
plt.plot(
    date,
    [23, 17, 17, 16, 15, 14, 17, 20],
    label="day temperature",
    linestyle="-.",
    color="#FF5733",
)
plt.plot(
    date,
    [19, 11, 16, 11, 10, 10, 11, 16],
    label="night temperature",
    linestyle=":",
    color="#061358",
)
plt.xlabel("Дата", fontsize="small", color="midnightblue")
plt.ylabel("Температура", fontsize="small", color="midnightblue")
plt.title("Температура в м. Полтава", fontsize=15)
plt.legend()
# plt.ylim(13, 23) # задання обмеження графіка по нижній та верхній межі
plt.grid(True) # графічна сітка
plt.show()

# %% [markdown]
# -  solid   - безперервна лінія
#
# -- dashed  - штрихова лінія
#
# -. dashdot - штрихпунктирна лінія
#
# :  dotted  - пунктирна лінія
#
# None пробіл або порожній рядок - не відображати лінію

# %% [markdown]
# Маркери

# %% [markdown]
# ![alt text](7bf1afbb-7a56-4fc1-9ea3-933c9522d990Screenshot_19-2.png)

# %%
import matplotlib.pyplot as plt
import pandas as pd

date = pd.date_range(start="2021-09-01", freq="D", periods=8)
plt.figure(figsize=(10, 6)) # (ширина, высота)
plt.plot(
    date,
    [23, 17, 17, 16, 15, 14, 17, 20],
    label="day temperature",
    linestyle="--",
    color="#FF5733",
    linewidth=2,
    marker="D",
)
plt.plot(
    date,
    [19, 11, 16, 11, 10, 10, 11, 16],
    label="night temperature",
    linestyle=":",
    color="#061358",
    linewidth=2,
    marker="^",
    markersize=10, # розмір маркера
)
plt.ylim(0, 25)
plt.xlabel("Дата", fontsize="small", color="midnightblue")
plt.ylabel("Температура", fontsize="small", color="midnightblue")
plt.title("Температура в м. Полтава", fontsize=15)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Стовпчикові діаграми

# %% [markdown]
# ![alt text](6eee5e7a-79a1-4595-8433-29309931df55Screenshot_20.png)

# %%
import matplotlib.pyplot as plt

plt.bar(
    ["США", "Китай", "Японія", "Велика Британія"],
    [39, 38, 27, 22],
    color=["b", "r", "y", "g"],
)

plt.xlabel("Країна", fontsize="small", color="midnightblue")
plt.ylabel("Кількість", fontsize="small", color="midnightblue")
plt.title("Золоті медалі: Літня олімпіада Токіо 2020", fontsize=15)
plt.show()

# %% [markdown]
# Кругові діаграми

# %% [markdown]
# ![alt text](42fdc5cb-9761-4072-afba-f2646460bbafScreenshot_21.png)

# %%
import matplotlib.pyplot as plt

labels = [
    "Junior Software Engineer",
    "Senior Software Engineer",
    "Software Engineer",
    "System Architect",
    "Technical Lead",
]

data = [63, 31, 100, 2, 11]
explode = [0.15, 0, 0, 0, 0] # відривання поля
plt.pie(
    data,
    labels=labels,
    shadow=True,
    explode=explode,
    autopct="%.2f%%", 
    pctdistance=1.15,
    labeldistance=1.35,
)

plt.show()

# %% [markdown]
# Діаграми в полярних координатах

# %%
import matplotlib.pyplot as plt
import numpy as np

theta = np.linspace(0, 2.0 * np.pi, 1000)

r = np.sin(6 * theta)
plt.polar(theta, r)
plt.show()

# %% [markdown]
# Тривимірні графіки

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# %% [markdown]
# Лінійний графік

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

theta_max = 8 * np.pi
n = 1000
theta = np.linspace(0, theta_max, n)
x = theta
z = np.sin(theta)
y = np.cos(theta)
ax.plot(x, y, z, "g")

plt.show()

# %% [markdown]
# Діаграма розсіювання

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

x = [5, 10, 15, 20]
z = [10, 0, 5, 15]
y = [0, 10, 5, 25]
s = [150, 130, 30, 160]
ax.scatter(x, y, z, s=s)

plt.show()

# %% [markdown]
# Каркасна поверхня

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

grid = np.arange(-10, 10, 0.5)
x, y = np.meshgrid(grid, grid)
z = x ** 2 * y ** 2 + 2

ax.plot_wireframe(x, y, z)

plt.show()

# %% [markdown]
# Поверхня

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection="3d")

grid = np.arange(-10, 10, 0.5)
x, y = np.meshgrid(grid, grid)
z = x ** 2 * y ** 2 + 2

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# Seaborn

# %% [markdown]
# pip install seaborn
#
# import seaborn as sns

# %%
import seaborn as sns

data = sns.load_dataset("mpg")

data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ​Візуалізація відносин в даних
#
# Seaborn надає функції для візуалізації відносин в даних у вигляді лінійних графіків та діаграм розсіювання.
#
# relplot Загальний інтерфейс для візуалізації відносин з параметрами для налаштування компонування.
# lineplot Лінійний графік із семантичним групуванням.
# scatterplot Діаграма розсіювання із семантичним групуванням.
#
# Загальні параметри функцій:
#
# x, y — пов'язують вісь x та y з конкретними ознаками з набору даних, переданого через параметр data. Дані повинні мати числовий тип. Фактично це назви стовпців із набору даних. Якщо вказати значення None, то побудова буде для всіх наборів відразу.
# data — набір даних у форматі pandas.DataFrame, у якому стовпці - це імена змінних, рядки - їх значення.
# ci — чисельно визначає розмір довірчого інтервалу, що відображається. Якщо присвоїти `sd', то використовує стандартне відхилення. Щоб не відображати, присвоїти None.
# hue — ім'я стовпця з набору data, який задає ознаку в наборі даних для колірного поділу даних.
# palette — палітра, яка буде використана для колірного поділу набору даних за значеннями ознаки, зазначеної в hue. Ім'я палітри можна вибрати відповідно до документації.
# hue_order — порядок застосування кольорів для даних з набору, переданого через параметр hue.
# size — ім'я стовпця з набору data, який буде використаний для поділу даних за розміром.
# size_order — задає порядок розподілу товщини лінії між елементами з набору даних, заданого через параметр size.
# style — ім'я стовпця з набору data, щоб задати ознаку в наборі даних, яка буде використана для поділу даних за стилем.
# markers — тип маркеру. Якщо параметр дорівнює False, то маркери не використовуватимуться.
# style_order — порядок застосування стилів.

# %% [markdown]
# Функція lineplot​

# %%
import pandas as pd
sns.set_style("whitegrid")

date = pd.date_range(start="2021-09-01", freq="D", periods=8)
day = [23, 17, 17, 16, 15, 14, 17, 20]
night = [19, 11, 16, 11, 10, 10, 11, 16]
df = pd.DataFrame({'date':date, 'day_temperature': day, 'night_temperature': night})

sns.lineplot(data=df)
# Out:
# <Axes: >

# %%
sns.lineplot(x="night_temperature", y="day_temperature", data=df)
# Out:
# <Axes: xlabel='night_temperature', ylabel='day_temperature'>

# %%
sns.lineplot(x="night_temperature", y="day_temperature", data=df, sort=False)
# Out:
# <Axes: xlabel='night_temperature', ylabel='day_temperature'>

# %%
sns.set_style("darkgrid")
data = sns.load_dataset("mpg")
sns.lineplot(x='model_year', y='horsepower', hue="origin", data=data)
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %% [markdown]
# Функція scatterplot

# %%
data = sns.load_dataset("mpg")
sns.scatterplot(x='mpg', y='displacement', data=data)
# Out:
# <Axes: xlabel='mpg', ylabel='displacement'>

# %%
sns.scatterplot(x='mpg', y='displacement', hue='origin', data=data)
# Out:
# <Axes: xlabel='mpg', ylabel='displacement'>

# %% [markdown]
# Функція relplot

# %%
sns.relplot(x='mpg', y='displacement', kind='scatter', data=data)

# %%
sns.relplot(x='mpg', y='displacement', kind='scatter', hue='origin', col='origin', data=data)

# %% [markdown]
# Візуалізація категоріальних даних
#
# Функція stripplot​

# %%
sns.stripplot(x='origin', y='mpg', data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.stripplot(x='origin', y='mpg', hue='cylinders', data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# Функція swarmplot​

# %%
sns.swarmplot(x='origin', y='mpg', data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# Візуалізації розподілу категоріальних даних

# %%
sns.boxplot(x="origin", y="mpg", hue="cylinders", data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x="origin", y="mpg", data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(x="origin", y="mpg", data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.boxenplot(x="origin", y="mpg", data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# Візуалізація оцінок категоріальних даних

# %% [markdown]
# Функція pointplot​

# %%
sns.pointplot(x="origin", y="mpg", data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# Функція barplot​

# %%
sns.barplot(x="origin", y="mpg", data=data)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# Функція countplot​

# %%
sns.countplot(x="cylinders", data=data)
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %% [markdown]
# Візуалізація моделі лінійної регресії

# %% [markdown]
# Функція regplot​

# %%
sns.lmplot(x="horsepower", y="displacement", data=data)

# %%
from numpy import median
sns.lmplot(x="horsepower", y="displacement", data=data, x_estimator=median)

# %% [markdown]
# Функція residplot​

# %%
sns.residplot(x="horsepower", y="displacement", data=data)
# Out:
# <Axes: xlabel='horsepower', ylabel='displacement'>

# %% [markdown]
# Функція lmplot​

# %%
sns.lmplot(x="horsepower", y="displacement", hue="origin", col="origin", data=data)

# %% [markdown]
# Візуальне оформлення графіків

# %% [markdown]
# Стилі

# %%
sns.set_style("darkgrid")
data = sns.load_dataset("mpg")
sns.lineplot(x='model_year', y='horsepower', hue="origin", data=data)
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style("darkgrid",  {'axes.facecolor': '#EAEAF2',
 'axes.edgecolor': 'white',
 'axes.grid': True,
 'axes.axisbelow': True,
 'axes.labelcolor': '.15',
 'figure.facecolor': 'white',
 'grid.color': 'white',
 'grid.linestyle': '-',
 'text.color': '.15',
 'xtick.color': '.15',
 'ytick.color': '.15',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'image.cmap': 'rocket',
 'font.family': ['sans-serif'],
 'font.sans-serif': ['Arial',
  'DejaVu Sans',
  'Liberation Sans',
  'Bitstream Vera Sans',
  'sans-serif'],
 'xtick.bottom': False,
 'xtick.top': False,
 'ytick.left': False,
 'ytick.right': False,
 'axes.spines.left': True,
 'axes.spines.bottom': True,
 'axes.spines.right': True,
 'axes.spines.top': True})
sns.lineplot(x='model_year', y='horsepower', hue="origin", data=data)
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %%
sns.set_style("darkgrid",  {'axes.labelcolor':"(0.5,0.5,0)", 'axes.edgecolor':'#061358',
'xtick.color':'#0A5806'})
sns.lineplot(x='model_year', y='horsepower', hue="origin", data=data)
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %% [markdown]
# Контекст

# %%
set_context(context=None, font_scale=1, rc=None)

# %%
sns.set_context("poster")
sns.scatterplot(x='mpg', y='displacement', data=data)
# Out:
# <Axes: xlabel='mpg', ylabel='displacement'>

# %% [markdown]
# Сітка

# %% [markdown]
# Параметри стилю для налаштування сітки
# ![alt text](cfa60d93-9f4d-4875-9125-0f046e449110Screenshot_23.png)

# %% [markdown]
# Параметри контексту для налаштування сітки
#
# ![alt text](3e76e167-b238-4acd-a9ce-4fe9cb908f42Screenshot_24.png)

# %% [markdown]
# Колір

# %%
color_palette(palette=None, n_colors=None, desat=None)

# %%
sns.palplot(sns.color_palette())
